# %% [markdown]
# # List

# %%
a = input("Movie1:")
b = input("Movie2:")
c = input("Movie3:")
d = list[a,b,c]
print(d)
# Out:
# list['ad', 'ds', 'fg']

# %%
a =  [1200, 1500, 900, 1700, 1100,2000, 1800]
print(max(a))
print(min(a))
# Out:
# 2000
# 900

# %%
a = ["Milk", "Bread", "Eggs"]
a.append("Butter")
print(a)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Butter']

# %%
a = [56, 78, 45, 90, 67]
print(sum(a))
print(sum(a)/len(a))
# Out:
# 336
# 67.2

# %%
a = ["Song A", "Song B", "Song C", "Song D"]
a.remove("Song C")
print(a)
# Out:
# ['Song A', 'Song B', 'Song D']

# %%
a = [15, 22, 34, 45, 19]
a.sort()
print(a)
# Out:
# [15, 19, 22, 34, 45]

# %%
a = ["Rahul", "Aman", "Vikram", "Sunil", "Ravi"]
a.remove("Vikram")
a.insert(2,"Kiran")
print(a)
# Out:
# ['Rahul', 'Aman', 'Kiran', 'Sunil', 'Ravi']

# %%
contacts1 = ["9998887771","9998887772"]
contacts2 = ["9998887773", "9998887774"]
contacts1.extend(contacts2)
print(contacts1)
# Out:
# ['9998887771', '9998887772', '9998887773', '9998887774']

# %%
a = [88, 45, 67, 45, 92, 45]
print(a.count(45))
# Out:
# 3

# %%
a = [4.5, 3.8, 4.9, 4.1, 3.5]
print(max(a))
# Out:
# 4.9

# %%
a = float(input("Product1:"))
b = float(input("Product2:"))
c = float(input("Product3:"))
d = float(input("Product4:"))
e = float(input("Product5:"))

# %%
i = [a,b,c,d,e]
print(sum(i))
# Out:
# 315.0

# %%
a = ["admin", "guest123", "root", "test_user"]
a.index("root")
# Out:
# 2
