# %% [markdown]
# # Python Basic Review

# %%
# Q1
hobby = "Playing Billiards"
Time_spent = 1
print(f"My favourite hobby is ",hobby, "and i spent",Time_spent*7,"hours per week")
# Out:
# My favourite hobby is  Playing Billiards and i spent 7 hours per week

# %%
# Q2
a = input("Enter your favourite Season:")
print("Your Favourite season is",a)
# Out:
# Your Favourite season is Winter

# %%
# Q3
num = "128"
print(type(num))
print(type(int(num)))
print("Next Token NO is:",int(num)+ 1)
# Out:
# <class 'str'>
# <class 'int'>
# Next Token NO is: 129

# %%
# Q4
a = 850, 320, 175, 60
b = list(a)
print((b))
print(sum(b))
# Out:
# [850, 320, 175, 60]
# 1405

# %%
# Q5
a = ("Math", "Science", "Art")
print(a[1])
# Out:
# Science

# %%
# Q6
a = " st. joseph college"
b = a.strip().title()
print(b)
# Out:
# St. Joseph College

# %%
# Q7
p = {"P1", "P4", "P7"}
print("P4" in p, ": P4 is Occuppied")
# Out:
# True : P4 is Occuppied

# %%
# Q8
a =  {"name": "Bruno", "breed":"Labrador", "age": 2}
print(a["breed"])
# Out:
# Labrador

# %%
# Q9
tags1 = ["sunset","portrait"]
tags2 = ["portrait", "wildlife"]
combined = tags1+tags2
print(set(combined))
# Out:
# {'portrait', 'sunset', 'wildlife'}

# %%
# Q10
a = 83
a *= 25
print("Converted Price is:",a)
# Out:
# Converted Price is: 2075

# %%
# Q11
oat = True
hot = True
custom = oat and hot
print(custom)
# Out:
# True

# %%
# Q12
a = "TRK458821"
print(len(a))
# Out:
# 9

# %%
# Q13
a = ("Kochi", "Dubai", "6 hours")
print("Duration is:",a[-1])
# Out:
# Duration is: 6 hours

# %%
# Q14
a = 1000
points = 7300//1000
print("Points earned is:",points)
# Out:
# Points earned is: 7

# %%
# Q15
a = 1200
a -= 350
print("New amount:",a)
# Out:
# New amount: 850
