# %% [markdown]
# # Strings

# %%
# Q1
a = "adhil"
print(a.upper())
# Out:
# ADHIL

# %%
email = "student@gmail.com"
print(len(email))
# Out:
# 17

# %%
a = "Amazing product, highly recommend!"
print(a.strip())
# Out:
# Amazing product, highly recommend!

# %%
a = input("Enter the Book name:")
print("Name:",a.title())
# Out:
# Name: The Alchemist

# %%
a = "We build apps for Java developers"
print(a.replace("Java","Python"))
# Out:
# We build apps for Python developers

# %%
a = input("Enter full name:")
print(a[ :4])
# Out:
# adhi

# %%
a = "Maths,Science,English,History"
print(a.split(","))
# Out:
# ['Maths', 'Science', 'English', 'History']

# %%
a = input("Enter a sentence:")
print(len(a))
# Out:
# 19

# %%
a = "Level"
b = a[ : :-1]
print(b)
print(a,b)
# Out:
# leveL
# Level leveL

# %%
a = "Banana"
print(a.count("a"))
# Out:
# 3

# %%
a = input("Ener your name:")
print(a.startswith("admin"))
# Out:
# False

# %%
a="17-09-2000"
print(a[-4: ])
# Out:
# 2000
